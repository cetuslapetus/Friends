# %% [markdown]
# <a href="https://colab.research.google.com/github/cetuslapetus/Friends/blob/main/RCNNPlayingCards.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow==2.4.1 tensorflow-gpu==2.4.1 keras==2.2.4
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !unzip /content/DATASET-20220727T231350Z-001.zip
# Out:
# Archive:  /content/DATASET-20220727T231350Z-001.zip
#   inflating: DATASET/test/annotations/IMG_2634.xml
#   inflating: DATASET/test/annotations/IMG_2560.xml
#   inflating: DATASET/test/annotations/IMG_2640.xml
#   inflating: DATASET/test/annotations/IMG_2600.xml
#   inflating: DATASET/test/annotations/IMG_2656.xml
#   inflating: DATASET/test/annotations/IMG_2580.xml
#   inflating: DATASET/test/annotations/IMG_2639.xml
#   inflating: DATASET/test/annotations/IMG_2573.xml
#   inflating: DATASET/test/annotations/IMG_2595.xml
#   inflating: DATASET/test/annotations/IMG_2557.xml
#   inflating: DATASET/test/annotations/IMG_2583.xml
#   inflating: DATASET/test/annotations/IMG_2591.xml
#   inflating: DATASET/test/annotations/IMG_2670.xml
#   inflating: DATASET/test/annotations/IMG_2594.xml
#   inflating: DATASET/test/annotations/IMG_2585.xml
#   inflating: DATASET/test/annotations/IMG_2604.xml
#   inflating: DATASET/test/annotations/IMG_2662.xml
# ...

# %%
# !pip install mrcnn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 51 kB 254 kB/s
# ...
#   Created wheel for mrcnn: filename=mrcnn-0.2-py3-none-any.whl size=54932 sha256=a10bfb36c3e5127b1b4d3298c97d90e6c0ac3adf9123a6c22c1c6766292edd06
#   Stored in directory: /root/.cache/pip/wheels/1d/94/0d/03ff96abc43d2d6c8299a92cbb4eced2a1eda3ca7911c19427
# Successfully built mrcnn
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import cv2
from os import listdir
from os import getcwd
import xml.etree.ElementTree as ET
from mrcnn.utils import Dataset

# %%
# load and parse the file
filename = '/content/DATASET/train/annotations/cam_image10.xml'
tree = ET.parse(filename)

# get the root of the document
root = tree.getroot()
